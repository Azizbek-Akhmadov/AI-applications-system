# %% [markdown]
# <a href="https://colab.research.google.com/github/Azizbek-Akhmadov/Mid-term-exam-AI-applications-system/blob/main/AI_application_week_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 import numpy as np

np.random.seed(3) # To make repeatable
LEARNING_RATE = 0.1
index_list = [0,1,2,3] # Used to randomize order

# Define training examples.
x_train = [np.array([1.0, -1.0, -1.0]),
           np.array([1.0, -1.0, 1.0]),
           np.array([1.0, 1.0, -1.0]),
           np.array([1.0, 1.0, 1.0])]
y_train = [0.0, 1.0, 1.0, 1.0, 0.0] # Output (ground truth)

# %%
def neuron_w(input_count):
  weights = np.zeros(input_count+1)
  for i in range(1, (input_count+1)):
    weights[i] = np.random.uniform(-1.0, 1.0)
  return weights

n_w = [neuron_w(2), neuron_w(2), neuron_w(2)]
n_y = [0,0,0]
n_error = [0,0,0]

# %%
def show_learning():
    print('Current weights:')
    for i, w in enumerate(n_w):
        print('neuron ', i, ': w0 =', '%5.2f' % w[0],
              ', w1 =', '%5.2f' % w[1], ', w2 =',
              '%5.2f' % w[2])
    print('----------------')

def forward_pass(x):
    global n_y
    n_y[0] = np.tanh(np.dot(n_w[0], x)) # Neuron 0
    n_y[1] = np.tanh(np.dot(n_w[1], x)) # Neuron 1
    n2_inputs = np.array([1.0, n_y[0], n_y[1]]) # 1.0 is bias
    z2 = np.dot(n_w[2], n2_inputs)
    n_y[2] = 1.0 / (1.0 + np.exp(-z2))

def backward_pass(y_truth):
    global n_error
    error_prime = -(y_truth - n_y[2]) # Derivative of loss-func
    derivative = n_y[2] * (1.0 - n_y[2]) # Logistic derivative
    n_error[2] = error_prime * derivative
    derivative = 1.0 - n_y[0]**2 # tanh derivative
    n_error[0] = n_w[2][1] * n_error[2] * derivative
    derivative = 1.0 - n_y[1]**2 # tanh derivative
    n_error[1] = n_w[2][2] * n_error[2] * derivative

def adjust_weights(x):
    global n_w
    n_w[0] -= (x * LEARNING_RATE * n_error[0])
    n_w[1] -= (x * LEARNING_RATE * n_error[1])
    n2_inputs = np.array([1.0, n_y[0], n_y[1]]) # 1.0 is bias
    n_w[2] -= (n2_inputs * LEARNING_RATE * n_error[2])

# %%
all_correct = False
while not all_correct: # Train until converged
    all_correct = True
    np.random.shuffle(index_list) # Randomize order
    for i in index_list: # Train on all examples
        forward_pass(x_train[i])
        backward_pass(y_train[i])
        adjust_weights(x_train[i])
        show_learning() # Show updated weights
    for i in range(len(x_train)): # Check if converged
        forward_pass(x_train[i])
        print('x1 =', '%4.1f' % x_train[i][1], ', x2 =',
              '%4.1f' % x_train[i][2], ', y =',
              '%.4f' % n_y[2])
        if(((y_train[i] < 0.5) and (n_y[2] >= 0.5))
                or ((y_train[i] >= 0.5) and (n_y[2] < 0.5))):
            all_correct = False
# Out:
# Current weights:
# neuron  0 : w0 =  0.00 , w1 =  0.02 , w2 =  0.78
# neuron  1 : w0 =  0.01 , w1 =  0.78 , w2 = -0.76
# neuron  2 : w0 = -0.01 , w1 = -0.58 , w2 = -0.90
# ----------------
# Current weights:
# neuron  0 : w0 =  0.00 , w1 =  0.01 , w2 =  0.78
# neuron  1 : w0 =  0.00 , w1 =  0.77 , w2 = -0.77
# neuron  2 : w0 = -0.00 , w1 = -0.57 , w2 = -0.90
# ----------------
# Current weights:
# neuron  0 : w0 = -0.00 , w1 =  0.01 , w2 =  0.78
# neuron  1 : w0 = -0.00 , w1 =  0.76 , w2 = -0.77
# neuron  2 : w0 =  0.01 , w1 = -0.58 , w2 = -0.88
# ----------------
# Current weights:
# neuron  0 : w0 = -0.01 , w1 =  0.01 , w2 =  0.78
# neuron  1 : w0 = -0.00 , w1 =  0.77 , w2 = -0.77
# neuron  2 : w0 =  0.02 , w1 = -0.57 , w2 = -0.89
# ----------------
# x1 = -1.0 , x2 = -1.0 , y = 0.5980
# x1 = -1.0 , x2 =  1.0 , y = 0.6159
# x1 =  1.0 , x2 = -1.0 , y = 0.3969
# x1 =  1.0 , x2 =  1.0 , y = 0.4163
# Current weights:
# neuron  0 : w0 = -0.01 , w1 =  0.01 , w2 =  0.78
# neuron  1 : w0 = -0.00 , w1 =  0.77 , w2 = -0.78
# neuron  2 : w0 =  0.03 , w1 = -0.56 , w2 = -0.90
# ----------------
# Current weights:
# neuron  0 : w0 = -0.01 , w1 =  0.01 , w2 =  0.77
# neuron  1 : w0 =  0.01 , w1 =  0.75 , w2 = -0.79
# neuron  2 : w0 =  0.02 , w1 = -0.55 , w2 = -0.90
# ----------------
# Current weights:
# neuron  0 : w0 = -0.01 , w1 =  0.00 , w2 =  0.78
# neuron  1 : w0 =  0.01 , w1 =  0.75 , w2 = -0.79
# neuron  2 : w0 =  0.03 , w1 = -0.56 , w2 = -0.89
# ----------------
# Current weights:
# neuron  0 : w0 = -0.02 , w1 = -0.00 , w2 =  0.77
# neuron  1 : w0 = -0.01 , w1 =  0.74 , w2 = -0.80
# neuron  2 : w0 =  0.05 , w1 = -0.55 , w2 = -0.89
# ----------------
# x1 = -1.0 , x2 = -1.0 , y = 0.5902
# x1 = -1.0 , x2 =  1.0 , y = 0.6231
# x1 =  1.0 , x2 = -1.0 , y = 0.4022
# x1 =  1.0 , x2 =  1.0 , y = 0.4381
# Current weights:
# neuron  0 : w0 = -0.02 , w1 = -0.00 , w2 =  0.77
# neuron  1 : w0 = -0.02 , w1 =  0.73 , w2 = -0.81
# neuron  2 : w0 =  0.06 , w1 = -0.55 , w2 = -0.89
# ----------------
# Current weights:
# neuron  0 : w0 = -0.02 , w1 = -0.00 , w2 =  0.76
# neuron  1 : w0 = -0.02 , w1 =  0.73 , w2 = -0.81
# neuron  2 : w0 =  0.07 , w1 = -0.54 , w2 = -0.90
# ----------------
# Current weights:
# neuron  0 : w0 = -0.02 , w1 = -0.01 , w2 =  0.76
# neuron  1 : w0 = -0.01 , w1 =  0.72 , w2 = -0.82
# neuron  2 : w0 =  0.06 , w1 = -0.53 , w2 = -0.90
# ----------------
# Current weights:
# neuron  0 : w0 = -0.02 , w1 = -0.01 , w2 =  0.76
# neuron  1 : w0 = -0.01 , w1 =  0.71 , w2 = -0.82
# neuron  2 : w0 =  0.07 , w1 = -0.54 , w2 = -0.88
# ----------------
# x1 = -1.0 , x2 = -1.0 , y = 0.5826
# x1 = -1.0 , x2 =  1.0 , y = 0.6301
# x1 =  1.0 , x2 = -1.0 , y = 0.4071
# x1 =  1.0 , x2 =  1.0 , y = 0.4594
# Current weights:
# neuron  0 : w0 = -0.03 , w1 = -0.01 , w2 =  0.76
# neuron  1 : w0 = -0.01 , w1 =  0.72 , w2 = -0.82
# neuron  2 : w0 =  0.08 , w1 = -0.53 , w2 = -0.89
# ----------------
# Current weights:
# neuron  0 : w0 = -0.03 , w1 = -0.01 , w2 =  0.76
# neuron  1 : w0 = -0.02 , w1 =  0.70 , w2 = -0.84
# neuron  2 : w0 =  0.09 , w1 = -0.53 , w2 = -0.89
# ----------------
# Current weights:
# neuron  0 : w0 = -0.03 , w1 = -0.02 , w2 =  0.76
# neuron  1 : w0 = -0.02 , w1 =  0.70 , w2 = -0.83
# neuron  2 : w0 =  0.11 , w1 = -0.54 , w2 = -0.88
# ----------------
# Current weights:
# neuron  0 : w0 = -0.03 , w1 = -0.02 , w2 =  0.76
# neuron  1 : w0 = -0.01 , w1 =  0.69 , w2 = -0.85
# neuron  2 : w0 =  0.09 , w1 = -0.53 , w2 = -0.88
# ----------------
# x1 = -1.0 , x2 = -1.0 , y = 0.5755
# x1 = -1.0 , x2 =  1.0 , y = 0.6371
# x1 =  1.0 , x2 = -1.0 , y = 0.4115
# x1 =  1.0 , x2 =  1.0 , y = 0.4799
# Current weights:
# neuron  0 : w0 = -0.03 , w1 = -0.03 , w2 =  0.76
# neuron  1 : w0 = -0.01 , w1 =  0.69 , w2 = -0.84
# neuron  2 : w0 =  0.11 , w1 = -0.54 , w2 = -0.87
# ----------------
# Current weights:
# neuron  0 : w0 = -0.04 , w1 = -0.03 , w2 =  0.76
# neuron  1 : w0 = -0.03 , w1 =  0.68 , w2 = -0.85
# neuron  2 : w0 =  0.12 , w1 = -0.53 , w2 = -0.87
# ----------------
# Current weights:
# neuron  0 : w0 = -0.04 , w1 = -0.03 , w2 =  0.75
# neuron  1 : w0 = -0.03 , w1 =  0.68 , w2 = -0.86
# neuron  2 : w0 =  0.13 , w1 = -0.52 , w2 = -0.88
# ----------------
# Current weights:
# neuron  0 : w0 = -0.04 , w1 = -0.03 , w2 =  0.75
# neuron  1 : w0 = -0.01 , w1 =  0.66 , w2 = -0.87
# neuron  2 : w0 =  0.11 , w1 = -0.51 , w2 = -0.88
# ----------------
# x1 = -1.0 , x2 = -1.0 , y = 0.5687
# x1 = -1.0 , x2 =  1.0 , y = 0.6439
# x1 =  1.0 , x2 = -1.0 , y = 0.4157
# x1 =  1.0 , x2 =  1.0 , y = 0.4993
# Current weights:
# neuron  0 : w0 = -0.04 , w1 = -0.04 , w2 =  0.75
# neuron  1 : w0 = -0.02 , w1 =  0.66 , w2 = -0.87
# neuron  2 : w0 =  0.13 , w1 = -0.52 , w2 = -0.87
# ----------------
# Current weights:
# neuron  0 : w0 = -0.05 , w1 = -0.04 , w2 =  0.75
# neuron  1 : w0 = -0.03 , w1 =  0.65 , w2 = -0.88
# neuron  2 : w0 =  0.14 , w1 = -0.52 , w2 = -0.87
# ----------------
# Current weights:
# neuron  0 : w0 = -0.05 , w1 = -0.04 , w2 =  0.75
# neuron  1 : w0 = -0.03 , w1 =  0.65 , w2 = -0.88
# neuron  2 : w0 =  0.15 , w1 = -0.51 , w2 = -0.88
# ----------------
# Current weights:
# neuron  0 : w0 = -0.04 , w1 = -0.04 , w2 =  0.74
# neuron  1 : w0 = -0.02 , w1 =  0.64 , w2 = -0.89
# neuron  2 : w0 =  0.13 , w1 = -0.50 , w2 = -0.88
# ----------------
# x1 = -1.0 , x2 = -1.0 , y = 0.5623
# x1 = -1.0 , x2 =  1.0 , y = 0.6506
# x1 =  1.0 , x2 = -1.0 , y = 0.4196
# x1 =  1.0 , x2 =  1.0 , y = 0.5177
# Current weights:
# neuron  0 : w0 = -0.04 , w1 = -0.05 , w2 =  0.74
# neuron  1 : w0 = -0.00 , w1 =  0.63 , w2 = -0.90
# neuron  2 : w0 =  0.12 , w1 = -0.49 , w2 = -0.88
# ----------------
# Current weights:
# neuron  0 : w0 = -0.04 , w1 = -0.05 , w2 =  0.73
# neuron  1 : w0 = -0.01 , w1 =  0.62 , w2 = -0.91
# neuron  2 : w0 =  0.13 , w1 = -0.49 , w2 = -0.89
# ----------------
# Current weights:
# neuron  0 : w0 = -0.05 , w1 = -0.05 , w2 =  0.73
# neuron  1 : w0 = -0.02 , w1 =  0.62 , w2 = -0.91
# neuron  2 : w0 =  0.14 , w1 = -0.48 , w2 = -0.89
# ----------------
# Current weights:
# neuron  0 : w0 = -0.05 , w1 = -0.05 , w2 =  0.74
# neuron  1 : w0 = -0.02 , w1 =  0.62 , w2 = -0.91
# neuron  2 : w0 =  0.15 , w1 = -0.49 , w2 = -0.88
# ----------------
# x1 = -1.0 , x2 = -1.0 , y = 0.5564
# x1 = -1.0 , x2 =  1.0 , y = 0.6570
# x1 =  1.0 , x2 = -1.0 , y = 0.4233
# x1 =  1.0 , x2 =  1.0 , y = 0.5352
# Current weights:
# neuron  0 : w0 = -0.05 , w1 = -0.05 , w2 =  0.74
# neuron  1 : w0 = -0.02 , w1 =  0.62 , w2 = -0.91
# neuron  2 : w0 =  0.17 , w1 = -0.50 , w2 = -0.87
# ----------------
# Current weights:
# neuron  0 : w0 = -0.05 , w1 = -0.06 , w2 =  0.73
# neuron  1 : w0 = -0.01 , w1 =  0.61 , w2 = -0.92
# neuron  2 : w0 =  0.15 , w1 = -0.49 , w2 = -0.87
# ----------------
# Current weights:
# neuron  0 : w0 = -0.05 , w1 = -0.06 , w2 =  0.73
# neuron  1 : w0 = -0.01 , w1 =  0.61 , w2 = -0.92
# neuron  2 : w0 =  0.16 , w1 = -0.49 , w2 = -0.88
# ----------------
# Current weights:
# neuron  0 : w0 = -0.05 , w1 = -0.06 , w2 =  0.73
# neuron  1 : w0 = -0.02 , w1 =  0.60 , w2 = -0.93
# neuron  2 : w0 =  0.17 , w1 = -0.48 , w2 = -0.88
# ----------------
# x1 = -1.0 , x2 = -1.0 , y = 0.5509
# x1 = -1.0 , x2 =  1.0 , y = 0.6633
# x1 =  1.0 , x2 = -1.0 , y = 0.4266
# x1 =  1.0 , x2 =  1.0 , y = 0.5516
# Current weights:
# neuron  0 : w0 = -0.06 , w1 = -0.06 , w2 =  0.73
# neuron  1 : w0 = -0.02 , w1 =  0.60 , w2 = -0.93
# neuron  2 : w0 =  0.19 , w1 = -0.49 , w2 = -0.87
# ----------------
# Current weights:
# neuron  0 : w0 = -0.05 , w1 = -0.07 , w2 =  0.73
# neuron  1 : w0 = -0.01 , w1 =  0.58 , w2 = -0.94
# neuron  2 : w0 =  0.17 , w1 = -0.48 , w2 = -0.87
# ----------------
# Current weights:
# neuron  0 : w0 = -0.06 , w1 = -0.07 , w2 =  0.73
# neuron  1 : w0 = -0.01 , w1 =  0.59 , w2 = -0.94
# neuron  2 : w0 =  0.18 , w1 = -0.48 , w2 = -0.88
# ----------------
# Current weights:
# neuron  0 : w0 = -0.06 , w1 = -0.07 , w2 =  0.72
# neuron  1 : w0 = -0.02 , w1 =  0.58 , w2 = -0.95
# neuron  2 : w0 =  0.19 , w1 = -0.47 , w2 = -0.88
# ----------------
# x1 = -1.0 , x2 = -1.0 , y = 0.5458
# x1 = -1.0 , x2 =  1.0 , y = 0.6694
# x1 =  1.0 , x2 = -1.0 , y = 0.4297
# x1 =  1.0 , x2 =  1.0 , y = 0.5670
# Current weights:
# neuron  0 : w0 = -0.06 , w1 = -0.07 , w2 =  0.72
# neuron  1 : w0 = -0.03 , w1 =  0.57 , w2 = -0.95
# neuron  2 : w0 =  0.20 , w1 = -0.47 , w2 = -0.89
# ----------------
# Current weights:
# neuron  0 : w0 = -0.07 , w1 = -0.07 , w2 =  0.72
# neuron  1 : w0 = -0.03 , w1 =  0.57 , w2 = -0.96
# neuron  2 : w0 =  0.21 , w1 = -0.46 , w2 = -0.89
# ----------------
# Current weights:
# neuron  0 : w0 = -0.06 , w1 = -0.07 , w2 =  0.71
# neuron  1 : w0 = -0.02 , w1 =  0.56 , w2 = -0.97
# neuron  2 : w0 =  0.20 , w1 = -0.45 , w2 = -0.90
# ----------------
# Current weights:
# neuron  0 : w0 = -0.07 , w1 = -0.08 , w2 =  0.72
# neuron  1 : w0 = -0.02 , w1 =  0.56 , w2 = -0.96
# neuron  2 : w0 =  0.21 , w1 = -0.46 , w2 = -0.89
# ----------------
# x1 = -1.0 , x2 = -1.0 , y = 0.5410
# x1 = -1.0 , x2 =  1.0 , y = 0.6752
# x1 =  1.0 , x2 = -1.0 , y = 0.4328
# x1 =  1.0 , x2 =  1.0 , y = 0.5815
# Current weights:
# neuron  0 : w0 = -0.06 , w1 = -0.08 , w2 =  0.71
# neuron  1 : w0 = -0.01 , w1 =  0.55 , w2 = -0.97
# neuron  2 : w0 =  0.20 , w1 = -0.45 , w2 = -0.89
# ----------------
# Current weights:
# neuron  0 : w0 = -0.06 , w1 = -0.08 , w2 =  0.71
# neuron  1 : w0 = -0.01 , w1 =  0.55 , w2 = -0.98
# neuron  2 : w0 =  0.20 , w1 = -0.45 , w2 = -0.90
# ----------------
# Current weights:
# neuron  0 : w0 = -0.07 , w1 = -0.08 , w2 =  0.71
# neuron  1 : w0 = -0.02 , w1 =  0.54 , w2 = -0.98
# neuron  2 : w0 =  0.21 , w1 = -0.44 , w2 = -0.90
# ----------------
# Current weights:
# neuron  0 : w0 = -0.07 , w1 = -0.09 , w2 =  0.71
# neuron  1 : w0 = -0.02 , w1 =  0.54 , w2 = -0.98
# neuron  2 : w0 =  0.23 , w1 = -0.45 , w2 = -0.89
# ----------------
# x1 = -1.0 , x2 = -1.0 , y = 0.5366
# x1 = -1.0 , x2 =  1.0 , y = 0.6808
# x1 =  1.0 , x2 = -1.0 , y = 0.4356
# x1 =  1.0 , x2 =  1.0 , y = 0.5951
# Current weights:
# neuron  0 : w0 = -0.07 , w1 = -0.09 , w2 =  0.71
# neuron  1 : w0 = -0.02 , w1 =  0.54 , w2 = -0.98
# neuron  2 : w0 =  0.24 , w1 = -0.46 , w2 = -0.88
# ----------------
# Current weights:
# neuron  0 : w0 = -0.07 , w1 = -0.09 , w2 =  0.71
# neuron  1 : w0 = -0.02 , w1 =  0.54 , w2 = -0.98
# neuron  2 : w0 =  0.25 , w1 = -0.46 , w2 = -0.88
# ----------------
# Current weights:
# neuron  0 : w0 = -0.08 , w1 = -0.09 , w2 =  0.71
# neuron  1 : w0 = -0.03 , w1 =  0.53 , w2 = -0.99
# neuron  2 : w0 =  0.26 , w1 = -0.46 , w2 = -0.89
# ----------------
# Current weights:
# neuron  0 : w0 = -0.07 , w1 = -0.10 , w2 =  0.70
# neuron  1 : w0 = -0.02 , w1 =  0.52 , w2 = -1.00
# neuron  2 : w0 =  0.25 , w1 = -0.45 , w2 = -0.89
# ----------------
# x1 = -1.0 , x2 = -1.0 , y = 0.5324
# x1 = -1.0 , x2 =  1.0 , y = 0.6862
# x1 =  1.0 , x2 = -1.0 , y = 0.4383
# x1 =  1.0 , x2 =  1.0 , y = 0.6078
# Current weights:
# neuron  0 : w0 = -0.07 , w1 = -0.10 , w2 =  0.70
# neuron  1 : w0 = -0.01 , w1 =  0.51 , w2 = -1.01
# neuron  2 : w0 =  0.23 , w1 = -0.44 , w2 = -0.90
# ----------------
# Current weights:
# neuron  0 : w0 = -0.07 , w1 = -0.10 , w2 =  0.70
# neuron  1 : w0 = -0.01 , w1 =  0.51 , w2 = -1.00
# neuron  2 : w0 =  0.25 , w1 = -0.45 , w2 = -0.89
# ----------------
# Current weights:
# neuron  0 : w0 = -0.08 , w1 = -0.11 , w2 =  0.70
# neuron  1 : w0 = -0.02 , w1 =  0.50 , w2 = -1.01
# neuron  2 : w0 =  0.26 , w1 = -0.44 , w2 = -0.89
# ----------------
# Current weights:
# neuron  0 : w0 = -0.08 , w1 = -0.10 , w2 =  0.70
# neuron  1 : w0 = -0.02 , w1 =  0.50 , w2 = -1.01
# neuron  2 : w0 =  0.26 , w1 = -0.44 , w2 = -0.90
# ----------------
# x1 = -1.0 , x2 = -1.0 , y = 0.5287
# x1 = -1.0 , x2 =  1.0 , y = 0.6914
# x1 =  1.0 , x2 = -1.0 , y = 0.4409
# x1 =  1.0 , x2 =  1.0 , y = 0.6197
# Current weights:
# neuron  0 : w0 = -0.08 , w1 = -0.11 , w2 =  0.70
# neuron  1 : w0 = -0.02 , w1 =  0.50 , w2 = -1.01
# neuron  2 : w0 =  0.28 , w1 = -0.45 , w2 = -0.88
# ----------------
# Current weights:
# neuron  0 : w0 = -0.08 , w1 = -0.10 , w2 =  0.70
# neuron  1 : w0 = -0.02 , w1 =  0.50 , w2 = -1.01
# neuron  2 : w0 =  0.28 , w1 = -0.45 , w2 = -0.89
# ----------------
# Current weights:
# neuron  0 : w0 = -0.09 , w1 = -0.11 , w2 =  0.70
# neuron  1 : w0 = -0.03 , w1 =  0.50 , w2 = -1.02
# neuron  2 : w0 =  0.29 , w1 = -0.44 , w2 = -0.89
# ----------------
# Current weights:
# neuron  0 : w0 = -0.08 , w1 = -0.11 , w2 =  0.69
# neuron  1 : w0 = -0.02 , w1 =  0.49 , w2 = -1.03
# neuron  2 : w0 =  0.28 , w1 = -0.43 , w2 = -0.90
# ----------------
# x1 = -1.0 , x2 = -1.0 , y = 0.5251
# x1 = -1.0 , x2 =  1.0 , y = 0.6964
# x1 =  1.0 , x2 = -1.0 , y = 0.4433
# x1 =  1.0 , x2 =  1.0 , y = 0.6309
# Current weights:
# neuron  0 : w0 = -0.09 , w1 = -0.11 , w2 =  0.69
# neuron  1 : w0 = -0.03 , w1 =  0.48 , w2 = -1.03
# neuron  2 : w0 =  0.29 , w1 = -0.43 , w2 = -0.90
# ----------------
# Current weights:
# neuron  0 : w0 = -0.08 , w1 = -0.12 , w2 =  0.69
# neuron  1 : w0 = -0.02 , w1 =  0.47 , w2 = -1.04
# neuron  2 : w0 =  0.27 , w1 = -0.42 , w2 = -0.91
# ----------------
# Current weights:
# neuron  0 : w0 = -0.08 , w1 = -0.12 , w2 =  0.68
# neuron  1 : w0 = -0.02 , w1 =  0.47 , w2 = -1.04
# neuron  2 : w0 =  0.28 , w1 = -0.42 , w2 = -0.92
# ----------------
# Current weights:
# neuron  0 : w0 = -0.09 , w1 = -0.12 , w2 =  0.69
# neuron  1 : w0 = -0.02 , w1 =  0.47 , w2 = -1.04
# neuron  2 : w0 =  0.29 , w1 = -0.43 , w2 = -0.90
# ----------------
# x1 = -1.0 , x2 = -1.0 , y = 0.5220
# x1 = -1.0 , x2 =  1.0 , y = 0.7012
# x1 =  1.0 , x2 = -1.0 , y = 0.4457
# x1 =  1.0 , x2 =  1.0 , y = 0.6414
# Current weights:
# neuron  0 : w0 = -0.09 , w1 = -0.12 , w2 =  0.69
# neuron  1 : w0 = -0.02 , w1 =  0.47 , w2 = -1.04
# neuron  2 : w0 =  0.30 , w1 = -0.42 , w2 = -0.91
# ----------------
# Current weights:
# neuron  0 : w0 = -0.09 , w1 = -0.12 , w2 =  0.69
# neuron  1 : w0 = -0.02 , w1 =  0.47 , w2 = -1.04
# neuron  2 : w0 =  0.31 , w1 = -0.43 , w2 = -0.90
# ----------------
# Current weights:
# neuron  0 : w0 = -0.09 , w1 = -0.12 , w2 =  0.68
# neuron  1 : w0 = -0.02 , w1 =  0.46 , w2 = -1.05
# neuron  2 : w0 =  0.30 , w1 = -0.43 , w2 = -0.90
# ----------------
# Current weights:
# neuron  0 : w0 = -0.09 , w1 = -0.13 , w2 =  0.68
# neuron  1 : w0 = -0.02 , w1 =  0.45 , w2 = -1.05
# neuron  2 : w0 =  0.31 , w1 = -0.42 , w2 = -0.91
# ----------------
# x1 = -1.0 , x2 = -1.0 , y = 0.5189
# x1 = -1.0 , x2 =  1.0 , y = 0.7057
# x1 =  1.0 , x2 = -1.0 , y = 0.4479
# x1 =  1.0 , x2 =  1.0 , y = 0.6513
# Current weights:
# neuron  0 : w0 = -0.09 , w1 = -0.13 , w2 =  0.68
# neuron  1 : w0 = -0.03 , w1 =  0.45 , w2 = -1.06
# neuron  2 : w0 =  0.32 , w1 = -0.42 , w2 = -0.91
# ----------------
# Current weights:
# neuron  0 : w0 = -0.09 , w1 = -0.13 , w2 =  0.67
# neuron  1 : w0 = -0.02 , w1 =  0.44 , w2 = -1.07
# neuron  2 : w0 =  0.30 , w1 = -0.41 , w2 = -0.92
# ----------------
# Current weights:
# neuron  0 : w0 = -0.09 , w1 = -0.14 , w2 =  0.68
# neuron  1 : w0 = -0.02 , w1 =  0.44 , w2 = -1.06
# neuron  2 : w0 =  0.32 , w1 = -0.42 , w2 = -0.91
# ----------------
# Current weights:
# neuron  0 : w0 = -0.09 , w1 = -0.13 , w2 =  0.68
# neuron  1 : w0 = -0.02 , w1 =  0.44 , w2 = -1.06
# neuron  2 : w0 =  0.32 , w1 = -0.42 , w2 = -0.91
# ----------------
# x1 = -1.0 , x2 = -1.0 , y = 0.5162
# x1 = -1.0 , x2 =  1.0 , y = 0.7101
# x1 =  1.0 , x2 = -1.0 , y = 0.4502
# x1 =  1.0 , x2 =  1.0 , y = 0.6607
# Current weights:
# neuron  0 : w0 = -0.10 , w1 = -0.14 , w2 =  0.67
# neuron  1 : w0 = -0.03 , w1 =  0.43 , w2 = -1.07
# neuron  2 : w0 =  0.33 , w1 = -0.42 , w2 = -0.92
# ----------------
# Current weights:
# neuron  0 : w0 = -0.10 , w1 = -0.14 , w2 =  0.67
# neuron  1 : w0 = -0.03 , w1 =  0.44 , w2 = -1.07
# neuron  2 : w0 =  0.34 , w1 = -0.41 , w2 = -0.92
# ----------------
# Current weights:
# neuron  0 : w0 = -0.09 , w1 = -0.14 , w2 =  0.67
# neuron  1 : w0 = -0.02 , w1 =  0.43 , w2 = -1.08
# neuron  2 : w0 =  0.32 , w1 = -0.40 , w2 = -0.93
# ----------------
# Current weights:
# neuron  0 : w0 = -0.10 , w1 = -0.14 , w2 =  0.67
# neuron  1 : w0 = -0.02 , w1 =  0.42 , w2 = -1.08
# neuron  2 : w0 =  0.34 , w1 = -0.41 , w2 = -0.92
# ----------------
# x1 = -1.0 , x2 = -1.0 , y = 0.5137
# x1 = -1.0 , x2 =  1.0 , y = 0.7143
# x1 =  1.0 , x2 = -1.0 , y = 0.4524
# x1 =  1.0 , x2 =  1.0 , y = 0.6695
# Current weights:
# neuron  0 : w0 = -0.10 , w1 = -0.14 , w2 =  0.67
# neuron  1 : w0 = -0.02 , w1 =  0.42 , w2 = -1.08
# neuron  2 : w0 =  0.34 , w1 = -0.41 , w2 = -0.92
# ----------------
# Current weights:
# neuron  0 : w0 = -0.10 , w1 = -0.15 , w2 =  0.66
# neuron  1 : w0 = -0.02 , w1 =  0.41 , w2 = -1.09
# neuron  2 : w0 =  0.33 , w1 = -0.40 , w2 = -0.93
# ----------------
# Current weights:
# neuron  0 : w0 = -0.10 , w1 = -0.15 , w2 =  0.67
# neuron  1 : w0 = -0.02 , w1 =  0.41 , w2 = -1.09
# neuron  2 : w0 =  0.35 , w1 = -0.41 , w2 = -0.92
# ----------------
# Current weights:
# neuron  0 : w0 = -0.10 , w1 = -0.15 , w2 =  0.67
# neuron  1 : w0 = -0.02 , w1 =  0.41 , w2 = -1.09
# neuron  2 : w0 =  0.35 , w1 = -0.41 , w2 = -0.92
# ----------------
# x1 = -1.0 , x2 = -1.0 , y = 0.5114
# x1 = -1.0 , x2 =  1.0 , y = 0.7184
# x1 =  1.0 , x2 = -1.0 , y = 0.4546
# x1 =  1.0 , x2 =  1.0 , y = 0.6779
# Current weights:
# neuron  0 : w0 = -0.10 , w1 = -0.15 , w2 =  0.66
# neuron  1 : w0 = -0.02 , w1 =  0.41 , w2 = -1.09
# neuron  2 : w0 =  0.36 , w1 = -0.41 , w2 = -0.93
# ----------------
# Current weights:
# neuron  0 : w0 = -0.10 , w1 = -0.16 , w2 =  0.66
# neuron  1 : w0 = -0.02 , w1 =  0.40 , w2 = -1.10
# neuron  2 : w0 =  0.35 , w1 = -0.40 , w2 = -0.93
# ----------------
# Current weights:
# neuron  0 : w0 = -0.10 , w1 = -0.16 , w2 =  0.66
# neuron  1 : w0 = -0.02 , w1 =  0.40 , w2 = -1.10
# neuron  2 : w0 =  0.36 , w1 = -0.41 , w2 = -0.92
# ----------------
# Current weights:
# neuron  0 : w0 = -0.10 , w1 = -0.16 , w2 =  0.66
# neuron  1 : w0 = -0.02 , w1 =  0.40 , w2 = -1.10
# neuron  2 : w0 =  0.36 , w1 = -0.41 , w2 = -0.93
# ----------------
# x1 = -1.0 , x2 = -1.0 , y = 0.5093
# x1 = -1.0 , x2 =  1.0 , y = 0.7222
# x1 =  1.0 , x2 = -1.0 , y = 0.4567
# x1 =  1.0 , x2 =  1.0 , y = 0.6858
# Current weights:
# neuron  0 : w0 = -0.11 , w1 = -0.16 , w2 =  0.66
# neuron  1 : w0 = -0.02 , w1 =  0.40 , w2 = -1.10
# neuron  2 : w0 =  0.38 , w1 = -0.42 , w2 = -0.91
# ----------------
# Current weights:
# neuron  0 : w0 = -0.10 , w1 = -0.16 , w2 =  0.66
# neuron  1 : w0 = -0.01 , w1 =  0.39 , w2 = -1.10
# neuron  2 : w0 =  0.37 , w1 = -0.41 , w2 = -0.92
# ----------------
# Current weights:
# neuron  0 : w0 = -0.10 , w1 = -0.16 , w2 =  0.66
# neuron  1 : w0 = -0.01 , w1 =  0.39 , w2 = -1.10
# neuron  2 : w0 =  0.37 , w1 = -0.41 , w2 = -0.93
# ----------------
# Current weights:
# neuron  0 : w0 = -0.10 , w1 = -0.16 , w2 =  0.66
# neuron  1 : w0 = -0.02 , w1 =  0.38 , w2 = -1.11
# neuron  2 : w0 =  0.38 , w1 = -0.40 , w2 = -0.93
# ----------------
# x1 = -1.0 , x2 = -1.0 , y = 0.5072
# x1 = -1.0 , x2 =  1.0 , y = 0.7260
# x1 =  1.0 , x2 = -1.0 , y = 0.4586
# x1 =  1.0 , x2 =  1.0 , y = 0.6932
# Current weights:
# neuron  0 : w0 = -0.11 , w1 = -0.16 , w2 =  0.65
# neuron  1 : w0 = -0.02 , w1 =  0.39 , w2 = -1.11
# neuron  2 : w0 =  0.38 , w1 = -0.40 , w2 = -0.94
# ----------------
# Current weights:
# neuron  0 : w0 = -0.10 , w1 = -0.17 , w2 =  0.65
# neuron  1 : w0 = -0.01 , w1 =  0.38 , w2 = -1.12
# neuron  2 : w0 =  0.37 , w1 = -0.39 , w2 = -0.94
# ----------------
# Current weights:
# neuron  0 : w0 = -0.11 , w1 = -0.17 , w2 =  0.65
# neuron  1 : w0 = -0.01 , w1 =  0.38 , w2 = -1.11
# neuron  2 : w0 =  0.38 , w1 = -0.40 , w2 = -0.93
# ----------------
# Current weights:
# neuron  0 : w0 = -0.11 , w1 = -0.17 , w2 =  0.65
# neuron  1 : w0 = -0.02 , w1 =  0.37 , w2 = -1.12
# neuron  2 : w0 =  0.39 , w1 = -0.40 , w2 = -0.94
# ----------------
# x1 = -1.0 , x2 = -1.0 , y = 0.5054
# x1 = -1.0 , x2 =  1.0 , y = 0.7295
# x1 =  1.0 , x2 = -1.0 , y = 0.4606
# x1 =  1.0 , x2 =  1.0 , y = 0.7003
# Current weights:
# neuron  0 : w0 = -0.10 , w1 = -0.17 , w2 =  0.65
# neuron  1 : w0 = -0.01 , w1 =  0.36 , w2 = -1.12
# neuron  2 : w0 =  0.38 , w1 = -0.39 , w2 = -0.94
# ----------------
# Current weights:
# neuron  0 : w0 = -0.11 , w1 = -0.18 , w2 =  0.65
# neuron  1 : w0 = -0.01 , w1 =  0.36 , w2 = -1.12
# neuron  2 : w0 =  0.39 , w1 = -0.40 , w2 = -0.93
# ----------------
# Current weights:
# neuron  0 : w0 = -0.11 , w1 = -0.18 , w2 =  0.65
# neuron  1 : w0 = -0.02 , w1 =  0.36 , w2 = -1.13
# neuron  2 : w0 =  0.40 , w1 = -0.40 , w2 = -0.93
# ----------------
# Current weights:
# neuron  0 : w0 = -0.11 , w1 = -0.18 , w2 =  0.65
# neuron  1 : w0 = -0.02 , w1 =  0.36 , w2 = -1.13
# neuron  2 : w0 =  0.40 , w1 = -0.40 , w2 = -0.94
# ----------------
# x1 = -1.0 , x2 = -1.0 , y = 0.5037
# x1 = -1.0 , x2 =  1.0 , y = 0.7329
# x1 =  1.0 , x2 = -1.0 , y = 0.4626
# x1 =  1.0 , x2 =  1.0 , y = 0.7071
# Current weights:
# neuron  0 : w0 = -0.11 , w1 = -0.18 , w2 =  0.64
# neuron  1 : w0 = -0.01 , w1 =  0.35 , w2 = -1.13
# neuron  2 : w0 =  0.39 , w1 = -0.39 , w2 = -0.95
# ----------------
# Current weights:
# neuron  0 : w0 = -0.11 , w1 = -0.18 , w2 =  0.65
# neuron  1 : w0 = -0.01 , w1 =  0.35 , w2 = -1.13
# neuron  2 : w0 =  0.40 , w1 = -0.40 , w2 = -0.94
# ----------------
# Current weights:
# neuron  0 : w0 = -0.11 , w1 = -0.18 , w2 =  0.64
# neuron  1 : w0 = -0.01 , w1 =  0.35 , w2 = -1.13
# neuron  2 : w0 =  0.41 , w1 = -0.40 , w2 = -0.94
# ----------------
# Current weights:
# neuron  0 : w0 = -0.11 , w1 = -0.19 , w2 =  0.64
# neuron  1 : w0 = -0.02 , w1 =  0.35 , w2 = -1.13
# neuron  2 : w0 =  0.42 , w1 = -0.40 , w2 = -0.94
# ----------------
# x1 = -1.0 , x2 = -1.0 , y = 0.5021
# x1 = -1.0 , x2 =  1.0 , y = 0.7362
# x1 =  1.0 , x2 = -1.0 , y = 0.4646
# x1 =  1.0 , x2 =  1.0 , y = 0.7135
# Current weights:
# neuron  0 : w0 = -0.11 , w1 = -0.18 , w2 =  0.64
# neuron  1 : w0 = -0.02 , w1 =  0.35 , w2 = -1.14
# neuron  2 : w0 =  0.42 , w1 = -0.39 , w2 = -0.95
# ----------------
# Current weights:
# neuron  0 : w0 = -0.12 , w1 = -0.19 , w2 =  0.64
# neuron  1 : w0 = -0.02 , w1 =  0.35 , w2 = -1.13
# neuron  2 : w0 =  0.43 , w1 = -0.40 , w2 = -0.94
# ----------------
# Current weights:
# neuron  0 : w0 = -0.11 , w1 = -0.19 , w2 =  0.64
# neuron  1 : w0 = -0.01 , w1 =  0.34 , w2 = -1.14
# neuron  2 : w0 =  0.42 , w1 = -0.40 , w2 = -0.95
# ----------------
# Current weights:
# neuron  0 : w0 = -0.11 , w1 = -0.19 , w2 =  0.64
# neuron  1 : w0 = -0.02 , w1 =  0.34 , w2 = -1.14
# neuron  2 : w0 =  0.43 , w1 = -0.40 , w2 = -0.95
# ----------------
# x1 = -1.0 , x2 = -1.0 , y = 0.5005
# x1 = -1.0 , x2 =  1.0 , y = 0.7393
# x1 =  1.0 , x2 = -1.0 , y = 0.4663
# x1 =  1.0 , x2 =  1.0 , y = 0.7196
# Current weights:
# neuron  0 : w0 = -0.11 , w1 = -0.20 , w2 =  0.63
# neuron  1 : w0 = -0.01 , w1 =  0.33 , w2 = -1.15
# neuron  2 : w0 =  0.41 , w1 = -0.39 , w2 = -0.96
# ----------------
# Current weights:
# neuron  0 : w0 = -0.11 , w1 = -0.19 , w2 =  0.63
# neuron  1 : w0 = -0.01 , w1 =  0.33 , w2 = -1.15
# neuron  2 : w0 =  0.42 , w1 = -0.39 , w2 = -0.96
# ----------------
# Current weights:
# neuron  0 : w0 = -0.11 , w1 = -0.20 , w2 =  0.63
# neuron  1 : w0 = -0.01 , w1 =  0.33 , w2 = -1.15
# neuron  2 : w0 =  0.42 , w1 = -0.38 , w2 = -0.97
# ----------------
# Current weights:
# neuron  0 : w0 = -0.12 , w1 = -0.20 , w2 =  0.63
# neuron  1 : w0 = -0.02 , w1 =  0.33 , w2 = -1.15
# neuron  2 : w0 =  0.44 , w1 = -0.39 , w2 = -0.95
# ----------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4992
# x1 = -1.0 , x2 =  1.0 , y = 0.7423
# x1 =  1.0 , x2 = -1.0 , y = 0.4683
# x1 =  1.0 , x2 =  1.0 , y = 0.7255
# Current weights:
# neuron  0 : w0 = -0.12 , w1 = -0.20 , w2 =  0.64
# neuron  1 : w0 = -0.02 , w1 =  0.32 , w2 = -1.15
# neuron  2 : w0 =  0.45 , w1 = -0.40 , w2 = -0.94
# ----------------
# Current weights:
# neuron  0 : w0 = -0.12 , w1 = -0.20 , w2 =  0.63
# neuron  1 : w0 = -0.02 , w1 =  0.32 , w2 = -1.15
# neuron  2 : w0 =  0.46 , w1 = -0.40 , w2 = -0.95
# ----------------
# Current weights:
# neuron  0 : w0 = -0.12 , w1 = -0.20 , w2 =  0.63
# neuron  1 : w0 = -0.02 , w1 =  0.32 , w2 = -1.15
# neuron  2 : w0 =  0.46 , w1 = -0.40 , w2 = -0.95
# ----------------
# Current weights:
# neuron  0 : w0 = -0.12 , w1 = -0.21 , w2 =  0.63
# neuron  1 : w0 = -0.01 , w1 =  0.31 , w2 = -1.16
# neuron  2 : w0 =  0.45 , w1 = -0.39 , w2 = -0.96
# ----------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4977
# x1 = -1.0 , x2 =  1.0 , y = 0.7452
# x1 =  1.0 , x2 = -1.0 , y = 0.4700
# x1 =  1.0 , x2 =  1.0 , y = 0.7311
# Current weights:
# neuron  0 : w0 = -0.12 , w1 = -0.20 , w2 =  0.63
# neuron  1 : w0 = -0.02 , w1 =  0.32 , w2 = -1.16
# neuron  2 : w0 =  0.45 , w1 = -0.39 , w2 = -0.96
# ----------------
# Current weights:
# neuron  0 : w0 = -0.12 , w1 = -0.21 , w2 =  0.62
# neuron  1 : w0 = -0.01 , w1 =  0.31 , w2 = -1.17
# neuron  2 : w0 =  0.44 , w1 = -0.38 , w2 = -0.97
# ----------------
# Current weights:
# neuron  0 : w0 = -0.12 , w1 = -0.21 , w2 =  0.62
# neuron  1 : w0 = -0.01 , w1 =  0.31 , w2 = -1.17
# neuron  2 : w0 =  0.45 , w1 = -0.38 , w2 = -0.97
# ----------------
# Current weights:
# neuron  0 : w0 = -0.12 , w1 = -0.21 , w2 =  0.62
# neuron  1 : w0 = -0.01 , w1 =  0.30 , w2 = -1.17
# neuron  2 : w0 =  0.46 , w1 = -0.39 , w2 = -0.96
# ----------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4965
# x1 = -1.0 , x2 =  1.0 , y = 0.7480
# x1 =  1.0 , x2 = -1.0 , y = 0.4719
# x1 =  1.0 , x2 =  1.0 , y = 0.7364
# Current weights:
# neuron  0 : w0 = -0.12 , w1 = -0.22 , w2 =  0.62
# neuron  1 : w0 = -0.01 , w1 =  0.30 , w2 = -1.17
# neuron  2 : w0 =  0.45 , w1 = -0.39 , w2 = -0.97
# ----------------
# Current weights:
# neuron  0 : w0 = -0.12 , w1 = -0.22 , w2 =  0.62
# neuron  1 : w0 = -0.01 , w1 =  0.30 , w2 = -1.17
# neuron  2 : w0 =  0.45 , w1 = -0.38 , w2 = -0.98
# ----------------
# Current weights:
# neuron  0 : w0 = -0.12 , w1 = -0.22 , w2 =  0.62
# neuron  1 : w0 = -0.01 , w1 =  0.30 , w2 = -1.17
# neuron  2 : w0 =  0.47 , w1 = -0.39 , w2 = -0.96
# ----------------
# Current weights:
# neuron  0 : w0 = -0.12 , w1 = -0.22 , w2 =  0.62
# neuron  1 : w0 = -0.01 , w1 =  0.29 , w2 = -1.17
# neuron  2 : w0 =  0.47 , w1 = -0.39 , w2 = -0.97
# ----------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4954
# x1 = -1.0 , x2 =  1.0 , y = 0.7507
# x1 =  1.0 , x2 = -1.0 , y = 0.4737
# x1 =  1.0 , x2 =  1.0 , y = 0.7416
# Current weights:
# neuron  0 : w0 = -0.12 , w1 = -0.22 , w2 =  0.62
# neuron  1 : w0 = -0.01 , w1 =  0.29 , w2 = -1.17
# neuron  2 : w0 =  0.48 , w1 = -0.39 , w2 = -0.97
# ----------------
# Current weights:
# neuron  0 : w0 = -0.12 , w1 = -0.22 , w2 =  0.62
# neuron  1 : w0 = -0.02 , w1 =  0.29 , w2 = -1.18
# neuron  2 : w0 =  0.48 , w1 = -0.39 , w2 = -0.98
# ----------------
# Current weights:
# neuron  0 : w0 = -0.13 , w1 = -0.22 , w2 =  0.62
# neuron  1 : w0 = -0.02 , w1 =  0.29 , w2 = -1.17
# neuron  2 : w0 =  0.49 , w1 = -0.40 , w2 = -0.96
# ----------------
# Current weights:
# neuron  0 : w0 = -0.12 , w1 = -0.23 , w2 =  0.62
# neuron  1 : w0 = -0.01 , w1 =  0.28 , w2 = -1.18
# neuron  2 : w0 =  0.48 , w1 = -0.39 , w2 = -0.97
# ----------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4942
# x1 = -1.0 , x2 =  1.0 , y = 0.7532
# x1 =  1.0 , x2 = -1.0 , y = 0.4754
# x1 =  1.0 , x2 =  1.0 , y = 0.7465
# Current weights:
# neuron  0 : w0 = -0.12 , w1 = -0.23 , w2 =  0.62
# neuron  1 : w0 = -0.02 , w1 =  0.28 , w2 = -1.18
# neuron  2 : w0 =  0.49 , w1 = -0.40 , w2 = -0.96
# ----------------
# Current weights:
# neuron  0 : w0 = -0.13 , w1 = -0.23 , w2 =  0.62
# neuron  1 : w0 = -0.02 , w1 =  0.28 , w2 = -1.18
# neuron  2 : w0 =  0.50 , w1 = -0.40 , w2 = -0.96
# ----------------
# Current weights:
# neuron  0 : w0 = -0.12 , w1 = -0.23 , w2 =  0.61
# neuron  1 : w0 = -0.01 , w1 =  0.27 , w2 = -1.19
# neuron  2 : w0 =  0.49 , w1 = -0.39 , w2 = -0.97
# ----------------
# Current weights:
# neuron  0 : w0 = -0.12 , w1 = -0.23 , w2 =  0.61
# neuron  1 : w0 = -0.01 , w1 =  0.27 , w2 = -1.19
# neuron  2 : w0 =  0.49 , w1 = -0.39 , w2 = -0.98
# ----------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4930
# x1 = -1.0 , x2 =  1.0 , y = 0.7557
# x1 =  1.0 , x2 = -1.0 , y = 0.4771
# x1 =  1.0 , x2 =  1.0 , y = 0.7513
# Current weights:
# neuron  0 : w0 = -0.13 , w1 = -0.23 , w2 =  0.61
# neuron  1 : w0 = -0.02 , w1 =  0.27 , w2 = -1.19
# neuron  2 : w0 =  0.50 , w1 = -0.39 , w2 = -0.98
# ----------------
# Current weights:
# neuron  0 : w0 = -0.13 , w1 = -0.24 , w2 =  0.61
# neuron  1 : w0 = -0.02 , w1 =  0.27 , w2 = -1.19
# neuron  2 : w0 =  0.51 , w1 = -0.40 , w2 = -0.97
# ----------------
# Current weights:
# neuron  0 : w0 = -0.13 , w1 = -0.24 , w2 =  0.61
# neuron  1 : w0 = -0.02 , w1 =  0.27 , w2 = -1.19
# neuron  2 : w0 =  0.51 , w1 = -0.40 , w2 = -0.97
# ----------------
# Current weights:
# neuron  0 : w0 = -0.12 , w1 = -0.24 , w2 =  0.61
# neuron  1 : w0 = -0.01 , w1 =  0.26 , w2 = -1.19
# neuron  2 : w0 =  0.50 , w1 = -0.39 , w2 = -0.98
# ----------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4918
# x1 = -1.0 , x2 =  1.0 , y = 0.7581
# x1 =  1.0 , x2 = -1.0 , y = 0.4787
# x1 =  1.0 , x2 =  1.0 , y = 0.7559
# Current weights:
# neuron  0 : w0 = -0.12 , w1 = -0.24 , w2 =  0.60
# neuron  1 : w0 = -0.01 , w1 =  0.26 , w2 = -1.20
# neuron  2 : w0 =  0.49 , w1 = -0.38 , w2 = -0.99
# ----------------
# Current weights:
# neuron  0 : w0 = -0.12 , w1 = -0.24 , w2 =  0.60
# neuron  1 : w0 = -0.01 , w1 =  0.26 , w2 = -1.20
# neuron  2 : w0 =  0.49 , w1 = -0.38 , w2 = -0.99
# ----------------
# Current weights:
# neuron  0 : w0 = -0.12 , w1 = -0.24 , w2 =  0.60
# neuron  1 : w0 = -0.01 , w1 =  0.26 , w2 = -1.20
# neuron  2 : w0 =  0.51 , w1 = -0.39 , w2 = -0.98
# ----------------
# Current weights:
# neuron  0 : w0 = -0.13 , w1 = -0.25 , w2 =  0.60
# neuron  1 : w0 = -0.01 , w1 =  0.25 , w2 = -1.20
# neuron  2 : w0 =  0.51 , w1 = -0.39 , w2 = -0.99
# ----------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4909
# x1 = -1.0 , x2 =  1.0 , y = 0.7604
# x1 =  1.0 , x2 = -1.0 , y = 0.4806
# x1 =  1.0 , x2 =  1.0 , y = 0.7603
# Current weights:
# neuron  0 : w0 = -0.13 , w1 = -0.25 , w2 =  0.60
# neuron  1 : w0 = -0.01 , w1 =  0.25 , w2 = -1.20
# neuron  2 : w0 =  0.51 , w1 = -0.39 , w2 = -0.99
# ----------------
# Current weights:
# neuron  0 : w0 = -0.13 , w1 = -0.25 , w2 =  0.60
# neuron  1 : w0 = -0.02 , w1 =  0.25 , w2 = -1.20
# neuron  2 : w0 =  0.53 , w1 = -0.40 , w2 = -0.98
# ----------------
# Current weights:
# neuron  0 : w0 = -0.13 , w1 = -0.25 , w2 =  0.60
# neuron  1 : w0 = -0.01 , w1 =  0.24 , w2 = -1.20
# neuron  2 : w0 =  0.52 , w1 = -0.39 , w2 = -0.99
# ----------------
# Current weights:
# neuron  0 : w0 = -0.13 , w1 = -0.25 , w2 =  0.60
# neuron  1 : w0 = -0.01 , w1 =  0.24 , w2 = -1.21
# neuron  2 : w0 =  0.52 , w1 = -0.39 , w2 = -0.99
# ----------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4899
# x1 = -1.0 , x2 =  1.0 , y = 0.7626
# x1 =  1.0 , x2 = -1.0 , y = 0.4822
# x1 =  1.0 , x2 =  1.0 , y = 0.7646
# Current weights:
# neuron  0 : w0 = -0.12 , w1 = -0.26 , w2 =  0.59
# neuron  1 : w0 = -0.01 , w1 =  0.24 , w2 = -1.21
# neuron  2 : w0 =  0.51 , w1 = -0.39 , w2 = -1.00
# ----------------
# Current weights:
# neuron  0 : w0 = -0.12 , w1 = -0.26 , w2 =  0.59
# neuron  1 : w0 = -0.01 , w1 =  0.24 , w2 = -1.21
# neuron  2 : w0 =  0.51 , w1 = -0.39 , w2 = -1.00
# ----------------
# Current weights:
# neuron  0 : w0 = -0.13 , w1 = -0.26 , w2 =  0.59
# neuron  1 : w0 = -0.01 , w1 =  0.24 , w2 = -1.21
# neuron  2 : w0 =  0.52 , w1 = -0.39 , w2 = -0.99
# ----------------
# Current weights:
# neuron  0 : w0 = -0.13 , w1 = -0.26 , w2 =  0.59
# neuron  1 : w0 = -0.01 , w1 =  0.24 , w2 = -1.21
# neuron  2 : w0 =  0.53 , w1 = -0.39 , w2 = -0.99
# ----------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4890
# x1 = -1.0 , x2 =  1.0 , y = 0.7647
# x1 =  1.0 , x2 = -1.0 , y = 0.4840
# x1 =  1.0 , x2 =  1.0 , y = 0.7687
# Current weights:
# neuron  0 : w0 = -0.13 , w1 = -0.26 , w2 =  0.59
# neuron  1 : w0 = -0.01 , w1 =  0.24 , w2 = -1.21
# neuron  2 : w0 =  0.53 , w1 = -0.39 , w2 = -1.00
# ----------------
# Current weights:
# neuron  0 : w0 = -0.13 , w1 = -0.26 , w2 =  0.59
# neuron  1 : w0 = -0.02 , w1 =  0.23 , w2 = -1.21
# neuron  2 : w0 =  0.55 , w1 = -0.40 , w2 = -0.99
# ----------------
# Current weights:
# neuron  0 : w0 = -0.13 , w1 = -0.26 , w2 =  0.59
# neuron  1 : w0 = -0.02 , w1 =  0.23 , w2 = -1.21
# neuron  2 : w0 =  0.55 , w1 = -0.40 , w2 = -0.99
# ----------------
# Current weights:
# neuron  0 : w0 = -0.13 , w1 = -0.27 , w2 =  0.59
# neuron  1 : w0 = -0.01 , w1 =  0.23 , w2 = -1.22
# neuron  2 : w0 =  0.54 , w1 = -0.39 , w2 = -1.00
# ----------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4880
# x1 = -1.0 , x2 =  1.0 , y = 0.7667
# x1 =  1.0 , x2 = -1.0 , y = 0.4857
# x1 =  1.0 , x2 =  1.0 , y = 0.7727
# Current weights:
# neuron  0 : w0 = -0.13 , w1 = -0.27 , w2 =  0.59
# neuron  1 : w0 = -0.01 , w1 =  0.22 , w2 = -1.21
# neuron  2 : w0 =  0.55 , w1 = -0.40 , w2 = -0.99
# ----------------
# Current weights:
# neuron  0 : w0 = -0.13 , w1 = -0.27 , w2 =  0.59
# neuron  1 : w0 = -0.02 , w1 =  0.22 , w2 = -1.21
# neuron  2 : w0 =  0.55 , w1 = -0.40 , w2 = -0.99
# ----------------
# Current weights:
# neuron  0 : w0 = -0.13 , w1 = -0.27 , w2 =  0.59
# neuron  1 : w0 = -0.02 , w1 =  0.22 , w2 = -1.22
# neuron  2 : w0 =  0.56 , w1 = -0.40 , w2 = -0.99
# ----------------
# Current weights:
# neuron  0 : w0 = -0.13 , w1 = -0.27 , w2 =  0.58
# neuron  1 : w0 = -0.01 , w1 =  0.22 , w2 = -1.22
# neuron  2 : w0 =  0.55 , w1 = -0.39 , w2 = -1.00
# ----------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4870
# x1 = -1.0 , x2 =  1.0 , y = 0.7686
# x1 =  1.0 , x2 = -1.0 , y = 0.4873
# x1 =  1.0 , x2 =  1.0 , y = 0.7766
# Current weights:
# neuron  0 : w0 = -0.13 , w1 = -0.27 , w2 =  0.58
# neuron  1 : w0 = -0.01 , w1 =  0.22 , w2 = -1.22
# neuron  2 : w0 =  0.55 , w1 = -0.39 , w2 = -1.01
# ----------------
# Current weights:
# neuron  0 : w0 = -0.13 , w1 = -0.27 , w2 =  0.58
# neuron  1 : w0 = -0.01 , w1 =  0.22 , w2 = -1.22
# neuron  2 : w0 =  0.55 , w1 = -0.39 , w2 = -1.01
# ----------------
# Current weights:
# neuron  0 : w0 = -0.13 , w1 = -0.28 , w2 =  0.58
# neuron  1 : w0 = -0.02 , w1 =  0.21 , w2 = -1.22
# neuron  2 : w0 =  0.57 , w1 = -0.40 , w2 = -1.00
# ----------------
# Current weights:
# neuron  0 : w0 = -0.13 , w1 = -0.28 , w2 =  0.58
# neuron  1 : w0 = -0.01 , w1 =  0.21 , w2 = -1.23
# neuron  2 : w0 =  0.55 , w1 = -0.40 , w2 = -1.01
# ----------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4861
# x1 = -1.0 , x2 =  1.0 , y = 0.7705
# x1 =  1.0 , x2 = -1.0 , y = 0.4889
# x1 =  1.0 , x2 =  1.0 , y = 0.7803
# Current weights:
# neuron  0 : w0 = -0.13 , w1 = -0.28 , w2 =  0.58
# neuron  1 : w0 = -0.01 , w1 =  0.21 , w2 = -1.23
# neuron  2 : w0 =  0.56 , w1 = -0.39 , w2 = -1.01
# ----------------
# Current weights:
# neuron  0 : w0 = -0.13 , w1 = -0.28 , w2 =  0.58
# neuron  1 : w0 = -0.01 , w1 =  0.21 , w2 = -1.22
# neuron  2 : w0 =  0.57 , w1 = -0.40 , w2 = -1.00
# ----------------
# Current weights:
# neuron  0 : w0 = -0.13 , w1 = -0.28 , w2 =  0.58
# neuron  1 : w0 = -0.01 , w1 =  0.20 , w2 = -1.23
# neuron  2 : w0 =  0.56 , w1 = -0.40 , w2 = -1.01
# ----------------
# Current weights:
# neuron  0 : w0 = -0.13 , w1 = -0.29 , w2 =  0.58
# neuron  1 : w0 = -0.01 , w1 =  0.20 , w2 = -1.23
# neuron  2 : w0 =  0.56 , w1 = -0.40 , w2 = -1.01
# ----------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4851
# x1 = -1.0 , x2 =  1.0 , y = 0.7722
# x1 =  1.0 , x2 = -1.0 , y = 0.4906
# x1 =  1.0 , x2 =  1.0 , y = 0.7839
# Current weights:
# neuron  0 : w0 = -0.13 , w1 = -0.29 , w2 =  0.58
# neuron  1 : w0 = -0.01 , w1 =  0.20 , w2 = -1.23
# neuron  2 : w0 =  0.58 , w1 = -0.41 , w2 = -1.00
# ----------------
# Current weights:
# neuron  0 : w0 = -0.13 , w1 = -0.29 , w2 =  0.57
# neuron  1 : w0 = -0.01 , w1 =  0.19 , w2 = -1.23
# neuron  2 : w0 =  0.56 , w1 = -0.40 , w2 = -1.01
# ----------------
# Current weights:
# neuron  0 : w0 = -0.13 , w1 = -0.29 , w2 =  0.57
# neuron  1 : w0 = -0.01 , w1 =  0.19 , w2 = -1.23
# neuron  2 : w0 =  0.57 , w1 = -0.40 , w2 = -1.01
# ----------------
# Current weights:
# neuron  0 : w0 = -0.13 , w1 = -0.29 , w2 =  0.57
# neuron  1 : w0 = -0.01 , w1 =  0.19 , w2 = -1.24
# neuron  2 : w0 =  0.57 , w1 = -0.40 , w2 = -1.02
# ----------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4842
# x1 = -1.0 , x2 =  1.0 , y = 0.7740
# x1 =  1.0 , x2 = -1.0 , y = 0.4922
# x1 =  1.0 , x2 =  1.0 , y = 0.7875
# Current weights:
# neuron  0 : w0 = -0.13 , w1 = -0.30 , w2 =  0.57
# neuron  1 : w0 = -0.01 , w1 =  0.19 , w2 = -1.24
# neuron  2 : w0 =  0.56 , w1 = -0.39 , w2 = -1.03
# ----------------
# Current weights:
# neuron  0 : w0 = -0.13 , w1 = -0.30 , w2 =  0.57
# neuron  1 : w0 = -0.01 , w1 =  0.19 , w2 = -1.24
# neuron  2 : w0 =  0.56 , w1 = -0.39 , w2 = -1.03
# ----------------
# Current weights:
# neuron  0 : w0 = -0.13 , w1 = -0.30 , w2 =  0.57
# neuron  1 : w0 = -0.01 , w1 =  0.18 , w2 = -1.24
# neuron  2 : w0 =  0.58 , w1 = -0.40 , w2 = -1.02
# ----------------
# Current weights:
# neuron  0 : w0 = -0.13 , w1 = -0.30 , w2 =  0.57
# neuron  1 : w0 = -0.01 , w1 =  0.18 , w2 = -1.24
# neuron  2 : w0 =  0.58 , w1 = -0.40 , w2 = -1.02
# ----------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4834
# x1 = -1.0 , x2 =  1.0 , y = 0.7756
# x1 =  1.0 , x2 = -1.0 , y = 0.4940
# x1 =  1.0 , x2 =  1.0 , y = 0.7909
# Current weights:
# neuron  0 : w0 = -0.13 , w1 = -0.30 , w2 =  0.56
# neuron  1 : w0 = -0.01 , w1 =  0.18 , w2 = -1.24
# neuron  2 : w0 =  0.57 , w1 = -0.40 , w2 = -1.03
# ----------------
# Current weights:
# neuron  0 : w0 = -0.13 , w1 = -0.31 , w2 =  0.56
# neuron  1 : w0 = -0.01 , w1 =  0.18 , w2 = -1.25
# neuron  2 : w0 =  0.57 , w1 = -0.40 , w2 = -1.03
# ----------------
# Current weights:
# neuron  0 : w0 = -0.13 , w1 = -0.30 , w2 =  0.56
# neuron  1 : w0 = -0.01 , w1 =  0.18 , w2 = -1.25
# neuron  2 : w0 =  0.57 , w1 = -0.39 , w2 = -1.04
# ----------------
# Current weights:
# neuron  0 : w0 = -0.13 , w1 = -0.31 , w2 =  0.56
# neuron  1 : w0 = -0.01 , w1 =  0.18 , w2 = -1.24
# neuron  2 : w0 =  0.59 , w1 = -0.40 , w2 = -1.03
# ----------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4827
# x1 = -1.0 , x2 =  1.0 , y = 0.7772
# x1 =  1.0 , x2 = -1.0 , y = 0.4959
# x1 =  1.0 , x2 =  1.0 , y = 0.7943
# Current weights:
# neuron  0 : w0 = -0.13 , w1 = -0.31 , w2 =  0.56
# neuron  1 : w0 = -0.01 , w1 =  0.18 , w2 = -1.24
# neuron  2 : w0 =  0.59 , w1 = -0.40 , w2 = -1.03
# ----------------
# Current weights:
# neuron  0 : w0 = -0.13 , w1 = -0.31 , w2 =  0.56
# neuron  1 : w0 = -0.01 , w1 =  0.17 , w2 = -1.25
# neuron  2 : w0 =  0.58 , w1 = -0.40 , w2 = -1.04
# ----------------
# Current weights:
# neuron  0 : w0 = -0.13 , w1 = -0.31 , w2 =  0.56
# neuron  1 : w0 = -0.01 , w1 =  0.17 , w2 = -1.25
# neuron  2 : w0 =  0.58 , w1 = -0.40 , w2 = -1.04
# ----------------
# Current weights:
# neuron  0 : w0 = -0.13 , w1 = -0.31 , w2 =  0.56
# neuron  1 : w0 = -0.01 , w1 =  0.17 , w2 = -1.25
# neuron  2 : w0 =  0.60 , w1 = -0.41 , w2 = -1.03
# ----------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4819
# x1 = -1.0 , x2 =  1.0 , y = 0.7787
# x1 =  1.0 , x2 = -1.0 , y = 0.4977
# x1 =  1.0 , x2 =  1.0 , y = 0.7975
# Current weights:
# neuron  0 : w0 = -0.13 , w1 = -0.31 , w2 =  0.56
# neuron  1 : w0 = -0.01 , w1 =  0.17 , w2 = -1.25
# neuron  2 : w0 =  0.60 , w1 = -0.41 , w2 = -1.03
# ----------------
# Current weights:
# neuron  0 : w0 = -0.13 , w1 = -0.32 , w2 =  0.56
# neuron  1 : w0 = -0.01 , w1 =  0.16 , w2 = -1.25
# neuron  2 : w0 =  0.61 , w1 = -0.41 , w2 = -1.02
# ----------------
# Current weights:
# neuron  0 : w0 = -0.13 , w1 = -0.32 , w2 =  0.55
# neuron  1 : w0 = -0.01 , w1 =  0.16 , w2 = -1.25
# neuron  2 : w0 =  0.60 , w1 = -0.41 , w2 = -1.03
# ----------------
# Current weights:
# neuron  0 : w0 = -0.13 , w1 = -0.32 , w2 =  0.55
# neuron  1 : w0 = -0.01 , w1 =  0.16 , w2 = -1.25
# neuron  2 : w0 =  0.60 , w1 = -0.41 , w2 = -1.04
# ----------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4809
# x1 = -1.0 , x2 =  1.0 , y = 0.7802
# x1 =  1.0 , x2 = -1.0 , y = 0.4994
# x1 =  1.0 , x2 =  1.0 , y = 0.8007
# Current weights:
# neuron  0 : w0 = -0.13 , w1 = -0.32 , w2 =  0.55
# neuron  1 : w0 = -0.01 , w1 =  0.16 , w2 = -1.25
# neuron  2 : w0 =  0.61 , w1 = -0.41 , w2 = -1.04
# ----------------
# Current weights:
# neuron  0 : w0 = -0.13 , w1 = -0.32 , w2 =  0.55
# neuron  1 : w0 = -0.01 , w1 =  0.16 , w2 = -1.25
# neuron  2 : w0 =  0.62 , w1 = -0.42 , w2 = -1.03
# ----------------
# Current weights:
# neuron  0 : w0 = -0.13 , w1 = -0.33 , w2 =  0.55
# neuron  1 : w0 = -0.01 , w1 =  0.15 , w2 = -1.26
# neuron  2 : w0 =  0.61 , w1 = -0.41 , w2 = -1.04
# ----------------
# Current weights:
# neuron  0 : w0 = -0.13 , w1 = -0.33 , w2 =  0.55
# neuron  1 : w0 = -0.01 , w1 =  0.15 , w2 = -1.26
# neuron  2 : w0 =  0.61 , w1 = -0.41 , w2 = -1.04
# ----------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4800
# x1 = -1.0 , x2 =  1.0 , y = 0.7816
# x1 =  1.0 , x2 = -1.0 , y = 0.5010
# x1 =  1.0 , x2 =  1.0 , y = 0.8038
